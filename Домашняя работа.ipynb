# %% [markdown]
# # Домашнее задание

# %% [markdown]
# 1. Загрузить файл titanic.csv

# %%
import pandas as pd

# %%
df = pd.read_csv("titanic (1).csv")
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %% [markdown]
# 2. Вывести основную информацию о наборе данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   891 non-null    int64
#  1   PassengerId  891 non-null    int64
#  2   Survived     891 non-null    int64
#  3   Pclass       891 non-null    int64
#  4   Name         891 non-null    object
#  5   Gender       891 non-null    object
#  6   Age          714 non-null    float64
#  7   SibSp        891 non-null    int64
#  8   Parch        891 non-null    int64
#  9   Ticket       891 non-null    object
#  10  Fare         891 non-null    float64
#  11  Cabin        204 non-null    object
#  12  Embarked     889 non-null    object
# dtypes: float64(2), int64(6), object(5)
# memory usage: 90.6+ KB

# %% [markdown]
# 3. Преобразовать столбец Gender в числовые значения – 0 и 1 для Male и Female соответственно.

# %%
df.Gender = df.Gender.replace({'male': 0, 'female': 1})
df
# Out:
# <ipython-input-4-4cf342760310>:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.Gender = df.Gender.replace({'male': 0, 'female': 1})
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 0             0            1         0       3
# 1             1            2         1       1
# 2             2            3         1       3
# 3             3            4         1       1
# 4             4            5         0       3
# ..          ...          ...       ...     ...
# 886         886          887         0       2
# 887         887          888         1       1
# 888         888          889         0       3
# 889         889          890         1       1
# 890         890          891         0       3
#
# ...

# %% [markdown]
# 5. Удалить строки, содержащие хотя бы одно значение NaN.

# %%
df = df.dropna()
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 1             1            2         1       1
# 3             3            4         1       1
# 6             6            7         0       1
# 10           10           11         1       3
# 11           11           12         1       1
# ..          ...          ...       ...     ...
# 871         871          872         1       1
# 872         872          873         0       1
# 879         879          880         1       1
# 887         887          888         1       1
# 889         889          890         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  35.0      1
# 6                              McCarthy, Mr. Timothy J       0  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut       1   4.0      1
# ...

# %% [markdown]
# 6. Визуализировать с помощью графиков значения полученного датафрейма.

# %%
import seaborn as sns

# %%
sns.barplot(
    x='Gender',
    y='Survived',
    data=df,
    palette='bright',
    hue='Pclass')
# Out:
# <Axes: xlabel='Gender', ylabel='Survived'>

# %% [markdown]
# 7. Обработать выбросы

# %%
sns.boxplot(df.Pclass)
# Out:
# <Axes: ylabel='Pclass'>

# %%
sns.boxplot(df.Age)
# Out:
# <Axes: ylabel='Age'>

# %%
for col in train_df.columns:
    Q3 = np.quantile(train_df[col], 0.75) # Методо quantile возвращет соответствующий квантиль набора данных
    Q1 = np.quantile(train_df[col], 0.25)
    IQR = Q3 - Q1 # Размах
    lower_range = Q1 - 1.5 * IQR #Нижний ус
    upper_range = Q3 + 1.5 * IQR #Верхний ус
    train_df = train_df[(train_df[col] >= lower_range) & (train_df[col] <= upper_range)] #Удаляем значения за пределами усов

train_df

# %% [markdown]
# 8. Перевести категориальные признаки в числовые

# %%
df.Cabin.value_counts()
# Out:
# Cabin
# G6             4
# B96 B98        4
# C23 C25 C27    4
# F33            3
# D              3
#               ..
# C91            1
# C124           1
# C32            1
# E34            1
# C148           1
# Name: count, Length: 133, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder() # Создаем экземпляр энкодера
label = le.fit_transform(df['Cabin']) # Обучаем и применяем Label кодирование
df.drop(columns='Cabin') # Удаляем столец с строковыми значениями
df['Cabin'] = label # Заменяем на числовые
df.Cabin.value_counts()
# Out:
# <ipython-input-16-0335ac0bad3b>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Cabin'] = label # Заменяем на числовые
# Cabin
# 131    4
# 41     4
# 55     4
# 129    3
# 80     3
#       ..
# 76     1
# 49     1
# 57     1
# 112    1
# 52     1
# Name: count, Length: 133, dtype: int64

# %% [markdown]
# 9. Сохранить полученный набор данных в файл "prepared_titanic.csv"

# %%
df.to_csv("prepared_titanic.csv")

# %% [markdown]
# 10. Нормализовать данные

# %%
df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  \
# 1             1            2         1       1
# 3             3            4         1       1
# 6             6            7         0       1
# 10           10           11         1       3
# 11           11           12         1       1
# ..          ...          ...       ...     ...
# 871         871          872         1       1
# 872         872          873         0       1
# 879         879          880         1       1
# 887         887          888         1       1
# 889         889          890         1       1
#
#                                                   Name  Gender   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...       1  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  35.0      1
# 6                              McCarthy, Mr. Timothy J       0  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut       1   4.0      1
# ...

# %%
df = df.drop(columns=['Name', 'Ticket', 'Embarked'])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
scaled_df = scaler.fit_transform(df.to_numpy())
scaled_df = pd.DataFrame(scaled_df, columns=df.columns)
scaled_df
# Out:
#      Unnamed: 0  PassengerId  Survived  Pclass  Gender       Age     SibSp  \
# 0      0.000000     0.000000       1.0     0.0     1.0  0.468892  0.333333
# 1      0.002252     0.002252       1.0     0.0     1.0  0.430956  0.333333
# 2      0.005631     0.005631       0.0     0.0     0.0  0.671219  0.000000
# 3      0.010135     0.010135       1.0     1.0     1.0  0.038948  0.333333
# 4      0.011261     0.011261       1.0     0.0     1.0  0.721801  0.000000
# ..          ...          ...       ...     ...     ...       ...       ...
# 178    0.979730     0.979730       1.0     0.0     1.0  0.582701  0.333333
# 179    0.980856     0.980856       0.0     0.0     0.0  0.405665  0.000000
# 180    0.988739     0.988739       1.0     0.0     1.0  0.696510  0.000000
# 181    0.997748     0.997748       1.0     0.0     1.0  0.228629  0.000000
# 182    1.000000     1.000000       1.0     0.0     0.0  0.317147  0.000000
#
#      Parch      Fare     Cabin
# 0     0.00  0.139136  0.545455
# ...

# %% [markdown]
# 11. Разделить набор данных на тренировочную и тестовую части

# %%
from sklearn.model_selection import train_test_split

# %%
X = scaled_df.drop(columns=['Unnamed: 0', 'PassengerId', 'Survived'])
y = scaled_df.Survived
X
# Out:
#      Pclass  Gender       Age     SibSp  Parch      Fare     Cabin
# 0       0.0     1.0  0.468892  0.333333   0.00  0.139136  0.545455
# 1       0.0     1.0  0.430956  0.333333   0.00  0.103644  0.363636
# 2       0.0     0.0  0.671219  0.000000   0.00  0.101229  0.886364
# 3       1.0     1.0  0.038948  0.333333   0.25  0.032596  0.992424
# 4       0.0     1.0  0.721801  0.000000   0.00  0.051822  0.325758
# ..      ...     ...       ...       ...    ...       ...       ...
# 178     0.0     1.0  0.582701  0.333333   0.25  0.102579  0.689394
# 179     0.0     0.0  0.405665  0.000000   0.00  0.009759  0.219697
# 180     0.0     1.0  0.696510  0.000000   0.25  0.162314  0.462121
# 181     0.0     1.0  0.228629  0.000000   0.00  0.058556  0.189394
# 182     0.0     0.0  0.317147  0.000000   0.00  0.058556  0.393939
#
# [183 rows x 7 columns]

# %%
y
# Out:
# 0      1.0
# 1      1.0
# 2      0.0
# 3      1.0
# 4      1.0
#       ...
# 178    1.0
# 179    0.0
# 180    1.0
# 181    1.0
# 182    1.0
# Name: Survived, Length: 183, dtype: float64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=1)

# %%
X_train
# Out:
#      Pclass  Gender       Age     SibSp  Parch      Fare     Cabin
# 19      0.0     0.0  0.291856  0.000000   0.25  0.483128  0.234848
# 93      0.0     0.0  0.582701  0.000000   0.00  0.075147  0.916667
# 114     0.0     1.0  0.481538  0.333333   0.25  0.155466  0.924242
# 124     0.0     1.0  0.494183  0.000000   0.00  0.299539  0.378788
# 90      0.0     0.0  0.607992  0.333333   0.00  0.173920  0.583333
# ..      ...     ...       ...       ...    ...       ...       ...
# 133     0.0     0.0  0.696510  0.000000   0.00  0.069291  0.037879
# 137     0.0     0.0  0.443601  0.000000   0.25  1.000000  0.219697
# 72      0.5     1.0  0.291856  0.000000   0.00  0.025374  0.977273
# 140     0.0     0.0  0.380374  0.333333   0.00  0.111257  0.113636
# 37      0.0     1.0  0.393020  0.000000   0.00  0.148911  0.628788
#
# [164 rows x 7 columns]

# %% [markdown]
# # 1. Импортировать набор данных *Baseball.txt*

# %% [markdown]
# # 2. Предподготовка данных

# %% [markdown]
# # Лассо Регрессия или L1-Регуляризация (Lasso)

# %% [markdown]
# # Ридж-регрессия или гребневая регрессия (Ridge)

# %% [markdown]
# # Эластичная сеть (ElasticNet)
